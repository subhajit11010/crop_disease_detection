# %%
import numpy as np
import pandas as pd
import sklearn
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv("data/crop_yield_dataset.csv")

# %%
df.head()
# Out:
#          Date Crop_Type Soil_Type  Soil_pH  Temperature   Humidity  \
# 0  2014-01-01     Wheat     Peaty     5.50     9.440599  80.000000
# 1  2014-01-01      Corn     Loamy     6.50    20.052576  79.947424
# 2  2014-01-01      Rice     Peaty     5.50    12.143099  80.000000
# 3  2014-01-01    Barley     Sandy     6.75    19.751848  80.000000
# 4  2014-01-01   Soybean     Peaty     5.50    16.110395  80.000000
#
#    Wind_Speed     N     P     K  Crop_Yield  Soil_Quality
# 0   10.956707  60.5  45.0  31.5    0.000000     22.833333
# 1    8.591577  84.0  66.0  50.0  104.871310     66.666667
# 2    7.227751  71.5  54.0  38.5    0.000000     27.333333
# 3    2.682683  50.0  40.0  30.0   58.939796     35.000000
# 4    7.696070  49.5  45.0  38.5   32.970413     22.166667

# %%
mod_df = df.copy()

# %%
mod_df.drop(columns=["Soil_pH", "Crop_Yield"], inplace=True)

# %%
mod_df.head()
# Out:
#          Date Crop_Type Soil_Type  Temperature   Humidity  Wind_Speed     N  \
# 0  2014-01-01     Wheat     Peaty     9.440599  80.000000   10.956707  60.5
# 1  2014-01-01      Corn     Loamy    20.052576  79.947424    8.591577  84.0
# 2  2014-01-01      Rice     Peaty    12.143099  80.000000    7.227751  71.5
# 3  2014-01-01    Barley     Sandy    19.751848  80.000000    2.682683  50.0
# 4  2014-01-01   Soybean     Peaty    16.110395  80.000000    7.696070  49.5
#
#       P     K  Soil_Quality
# 0  45.0  31.5     22.833333
# 1  66.0  50.0     66.666667
# 2  54.0  38.5     27.333333
# 3  40.0  30.0     35.000000
# 4  45.0  38.5     22.166667

# %%
mod_df["Crop_Type"].value_counts()
# Out:
# Crop_Type
# Wheat        3652
# Corn         3652
# Rice         3652
# Barley       3652
# Soybean      3652
# Cotton       3652
# Sugarcane    3652
# Tomato       3652
# Potato       3652
# Sunflower    3652
# Name: count, dtype: int64

# %%
mod_df = mod_df[mod_df["Crop_Type"].isin(["Wheat", "Rice", "Tomato"])]

# %%
mod_df.head()
# Out:
#           Date Crop_Type Soil_Type  Temperature  Humidity  Wind_Speed     N  \
# 0   2014-01-01     Wheat     Peaty     9.440599      80.0   10.956707  60.5
# 2   2014-01-01      Rice     Peaty    12.143099      80.0    7.227751  71.5
# 7   2014-01-01    Tomato      Clay    18.323272      80.0    8.198084  60.0
# 10  2014-01-02     Wheat     Peaty    16.044318      80.0    4.120990  60.5
# 12  2014-01-02      Rice     Peaty    14.421759      80.0    9.096689  71.5
#
#        P     K  Soil_Quality
# 0   45.0  31.5     22.833333
# 2   54.0  38.5     27.333333
# 7   45.0  40.0     42.291667
# 10  45.0  31.5     22.833333
# 12  54.0  38.5     27.333333

# %%
sns.histplot(mod_df["Soil_Quality"])
# Out:
# <Axes: xlabel='Soil_Quality', ylabel='Count'>

# %%
mod_df
# Out:
#       Crop_Type  Temperature   Humidity  Wind_Speed     N     P     K  \
# 0         Wheat     9.440599  80.000000   10.956707  60.5  45.0  31.5
# 2          Rice    12.143099  80.000000    7.227751  71.5  54.0  38.5
# 7        Tomato    18.323272  80.000000    8.198084  60.0  45.0  40.0
# 10        Wheat    16.044318  80.000000    4.120990  60.5  45.0  31.5
# 12         Rice    14.421759  80.000000    9.096689  71.5  54.0  38.5
# ...         ...          ...        ...         ...   ...   ...   ...
# 36502      Rice     9.629740  80.000000    9.134019  65.0  48.0  33.0
# 36507    Tomato    20.021899  79.978101   14.829451  55.0  40.5  35.0
# 36510     Wheat     4.334143  80.000000    7.450685  60.5  45.0  31.5
# 36512      Rice     3.994628  80.000000   14.388341  65.0  48.0  33.0
# 36517    Tomato     6.030148  80.000000    9.409497  50.0  36.0  30.0
#
#        Soil_Quality
# 0         22.833333
# 2         27.333333
# 7         42.291667
# 10        22.833333
# ...

# %%
mod_df = pd.get_dummies(mod_df, columns=["Crop_Type"], dtype=int)

# %%
mod_df.head()
# Out:
#     Temperature  Humidity  Wind_Speed     N     P     K  Soil_Quality  \
# 0      9.440599      80.0   10.956707  60.5  45.0  31.5     22.833333
# 2     12.143099      80.0    7.227751  71.5  54.0  38.5     27.333333
# 7     18.323272      80.0    8.198084  60.0  45.0  40.0     42.291667
# 10    16.044318      80.0    4.120990  60.5  45.0  31.5     22.833333
# 12    14.421759      80.0    9.096689  71.5  54.0  38.5     27.333333
#
#     Crop_Type_Rice  Crop_Type_Tomato  Crop_Type_Wheat
# 0                0                 0                1
# 2                1                 0                0
# 7                0                 1                0
# 10               0                 0                1
# 12               1                 0                0

# %%
X = mod_df.drop("Soil_Quality", axis=1)
y = mod_df["Soil_Quality"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, shuffle=True)

# %%
scaler = StandardScaler()
num_cols = ["N", "P", "K", "Temperature", "Humidity", "Wind_Speed"]
X[num_cols] = scaler.fit_transform(X[num_cols])

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print(" Linear Regression RMSE:", rmse)
# Out:
#  Linear Regression RMSE: 16.38597407556736

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test, y_pred)
print(" Linear Regression R2 Score :", r2*100,'%')
# Out:
#  Linear Regression R2 Score : 13.919257437368405 %

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import cross_validate
knn = KNeighborsRegressor()

knnResults = cross_validate(knn, X_train, np.ravel(y_train), cv=5, scoring='r2')
mean_r2 = np.mean(knnResults['test_score'])
print('KNN R2:', mean_r2)
# Out:
# KNN R2: 0.9983705651916708

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsRegressor()

# %%
from sklearn.metrics import r2_score, mean_squared_error
y_pred = knn.predict(X_test)

print("Test R²:", r2_score(y_test, y_pred))
print("Test RMSE:", mean_squared_error(y_test, y_pred))
# Out:
# Test R²: 0.9989301365966785
# Test RMSE: 0.33370818126520657

# %%
import joblib

joblib.dump(knn, "model.pkl")
joblib.dump(scaler, "scaler.pkl")
# Out:
# ['scaler.pkl']

# %%
X
# Out:
#        Temperature  Humidity  Wind_Speed         N         P         K  \
# 0        -1.614837  0.848753    0.315609 -0.676243 -0.685423 -1.082269
# 2        -1.311287  0.848753   -0.922423  0.328852  0.252639 -0.182027
# 7        -0.617120  0.848753   -0.600268 -0.721929 -0.685423  0.010882
# 10       -0.873096  0.848753   -1.953885 -0.676243 -0.685423 -1.082269
# 12       -1.055345  0.848753   -0.301926  0.328852  0.252639 -0.182027
# ...            ...       ...         ...       ...       ...       ...
# 36502    -1.593592  0.848753   -0.289533 -0.265068 -0.372736 -0.889360
# 36507    -0.426327  0.845512    1.601381 -1.178791 -1.154454 -0.632148
# 36510    -2.188402  0.848753   -0.848408 -0.676243 -0.685423 -1.082269
# 36512    -2.226537  0.848753    1.454930 -0.265068 -0.372736 -0.889360
# 36517    -1.997904  0.848753   -0.198073 -1.635652 -1.623485 -1.275178
#
#        Crop_Type_Rice  Crop_Type_Tomato  Crop_Type_Wheat
# 0                   0                 0                1
# ...
